# %% [markdown]
# # Numpy stack consists of numpy, pandas, scipy and matplotlib
#
# # This file is primarily for numpy

# %% [markdown]
# a list can contain an integer, char, boolean and another list in python, but a numpy array is specifically designed for numerical work.

# %%
import numpy as np


x = np.array([
    [1.2, 5.0, 7.1],
    [2.4, 4.2, 8.0],
    [3.1, 6.3, 6.8],
])

x.shape
# Out:
# (3, 3)

# %%
x.size
# Out:
# 9

# %%
x.ndim
# Out:
# 2

# %%
x.dtype
# Out:
# dtype('float64')

# %% [markdown]
# IN ml rows = observations/samples
# and columns = features and measurements.

# %% [markdown]
# so if an array is shaped (10000, 3). it means it has 10000 observations and 3 features per observation.

# %%
L = [1, 2, 3]
A = np.array([1, 2, 3])

# %%
L + [4]
# Out:
# [1, 2, 3, 4]

# %%
A + 4
# Out:
# array([5, 6, 7])

# %%
A + np.array([5, 6, 7])
# Out:
# array([ 6,  8, 10])

# %%
# multiplacation

2 * L
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
2 * A
# Out:
# array([2, 4, 6])

# %%
# mathematical functions in numpy arrays
np.sqrt(A)
np.log(A)
np.exp(A)
np.sin(A)
np.tanh(A)
A ** 2
# Out:
# array([1, 4, 9])

# %%
X = np.array([
    [10, 100],
    [20, 200],
    [30, 300],
])

column_means = X.mean(axis=0)
print(column_means)
centred = X - column_means
# Out:
# 110.0

# %%
c = np.array([[2, 3],
              [4, 5]])

# %%
np.linalg.eig(c)
# Out:
# EigResult(eigenvalues=array([-0.27491722+0.j,  7.27491722+0.j]), eigenvectors=array([[-0.79681209+0.j, -0.49436913+0.j],
#        [ 0.60422718+0.j, -0.86925207+0.j]]))

# %%
np.linalg.inv(c).dot(c)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
Lam, V = np.linalg.eig(c)
print(Lam, V)
# Out:
# [-0.27491722+0.j  7.27491722+0.j] [[-0.79681209+0.j -0.49436913+0.j]
#  [ 0.60422718+0.j -0.86925207+0.j]]

# %%
np.zeros((2, 3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.random.random((2, 3))
# Out:
# array([[0.03751436, 0.97709807, 0.08069365],
#        [0.25921425, 0.65673241, 0.39617197]])

# %%
np.random.randn(2, 3)
# Out:
# array([[-0.37999976, -1.769146  ,  0.53200165],
#        [-0.71521991,  0.83206523, -1.06278368]])

# %%
R = np.random.randn(10000)

# %%
R.mean()
# Out:
# np.float64(-0.010150240671163506)

# %%
R = np.random.randn(10000, 3)

# %%
R.mean(axis= 0) # calculates the mean of each column
# Out:
# array([-0.00298372, -0.0117455 , -0.00707099])

# %%
R.mean(axis= 1).shape # calculates the mean of each row
# Out:
# (10000,)

# %%
np.cov(R).shape
# Out:
# (10000, 10000)

# %%
np.random.randint(0 , 10 , size = (3, 3))
# Out:
# array([[0, 1, 4],
#        [4, 0, 4],
#        [2, 5, 1]])
